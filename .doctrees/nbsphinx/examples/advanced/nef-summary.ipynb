# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book "Neural Engineering"](
# https://www.amazon.com/Neural-Engineering-Representation-Neurobiological-Computational/dp/0262550601).
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1125642158" href="javascript:toggle_input_1125642158()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1125642158;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1125642158 = document.getElementById("1125642158");
#                 var cell = link_1125642158;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1125642158;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1125642158 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1125642158 = cell.previousElementSibling;
#                 }
#                 input_1125642158.style.display = "none"; // hide
#
#                 toggle_input_1125642158 = function() {
#                     if (input_1125642158.style.display == "none") {
#                         input_1125642158.style.display = ""; // show
#                         link_1125642158.innerHTML = "Hide Input";
#                     } else {
#                         input_1125642158.style.display = "none"; // hide
#                         link_1125642158.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1125642158 = $("a[id='1125642158']");
#                 var cell_1125642158 = link_1125642158.parents("div.cell:first");
#                 if (cell_1125642158.length == 0) {
#                     cell_1125642158 = link_1125642158.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1125642158 = cell_1125642158.children("div.input");
#                 if (input_1125642158.length == 0) {
#                     input_1125642158 = cell_1125642158.prev("div.nbinput");
#                 }
#                 input_1125642158.hide();
#
#                 toggle_input_1125642158 = function() {
#                     if (input_1125642158.is(':hidden')) {
#                         input_1125642158.slideDown();
#                         link_1125642158[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1125642158.slideUp();
#                         link_1125642158[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1715376896" href="javascript:toggle_input_1715376896()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1715376896;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1715376896 = document.getElementById("1715376896");
#                 var cell = link_1715376896;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1715376896;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1715376896 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1715376896 = cell.previousElementSibling;
#                 }
#                 input_1715376896.style.display = "none"; // hide
#
#                 toggle_input_1715376896 = function() {
#                     if (input_1715376896.style.display == "none") {
#                         input_1715376896.style.display = ""; // show
#                         link_1715376896.innerHTML = "Hide Input";
#                     } else {
#                         input_1715376896.style.display = "none"; // hide
#                         link_1715376896.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1715376896 = $("a[id='1715376896']");
#                 var cell_1715376896 = link_1715376896.parents("div.cell:first");
#                 if (cell_1715376896.length == 0) {
#                     cell_1715376896 = link_1715376896.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1715376896 = cell_1715376896.children("div.input");
#                 if (input_1715376896.length == 0) {
#                     input_1715376896 = cell_1715376896.prev("div.nbinput");
#                 }
#                 input_1715376896.hide();
#
#                 toggle_input_1715376896 = function() {
#                     if (input_1715376896.is(':hidden')) {
#                         input_1715376896.slideDown();
#                         link_1715376896[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1715376896.slideUp();
#                         link_1715376896[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="1675753522" href="javascript:toggle_input_1675753522()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1675753522;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1675753522 = document.getElementById("1675753522");
#                 var cell = link_1675753522;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1675753522;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1675753522 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1675753522 = cell.previousElementSibling;
#                 }
#                 input_1675753522.style.display = "none"; // hide
#
#                 toggle_input_1675753522 = function() {
#                     if (input_1675753522.style.display == "none") {
#                         input_1675753522.style.display = ""; // show
#                         link_1675753522.innerHTML = "Hide Input";
#                     } else {
#                         input_1675753522.style.display = "none"; // hide
#                         link_1675753522.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1675753522 = $("a[id='1675753522']");
#                 var cell_1675753522 = link_1675753522.parents("div.cell:first");
#                 if (cell_1675753522.length == 0) {
#                     cell_1675753522 = link_1675753522.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1675753522 = cell_1675753522.children("div.input");
#                 if (input_1675753522.length == 0) {
#                     input_1675753522 = cell_1675753522.prev("div.nbinput");
#                 }
#                 input_1675753522.hide();
#
#                 toggle_input_1675753522 = function() {
#                     if (input_1675753522.is(':hidden')) {
#                         input_1675753522.slideDown();
#                         link_1675753522[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1675753522.slideUp();
#                         link_1675753522[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="1849186509" href="javascript:toggle_input_1849186509()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1849186509;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1849186509 = document.getElementById("1849186509");
#                 var cell = link_1849186509;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1849186509;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1849186509 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1849186509 = cell.previousElementSibling;
#                 }
#                 input_1849186509.style.display = "none"; // hide
#
#                 toggle_input_1849186509 = function() {
#                     if (input_1849186509.style.display == "none") {
#                         input_1849186509.style.display = ""; // show
#                         link_1849186509.innerHTML = "Hide Input";
#                     } else {
#                         input_1849186509.style.display = "none"; // hide
#                         link_1849186509.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1849186509 = $("a[id='1849186509']");
#                 var cell_1849186509 = link_1849186509.parents("div.cell:first");
#                 if (cell_1849186509.length == 0) {
#                     cell_1849186509 = link_1849186509.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1849186509 = cell_1849186509.children("div.input");
#                 if (input_1849186509.length == 0) {
#                     input_1849186509 = cell_1849186509.prev("div.nbinput");
#                 }
#                 input_1849186509.hide();
#
#                 toggle_input_1849186509 = function() {
#                     if (input_1849186509.is(':hidden')) {
#                         input_1849186509.slideDown();
#                         link_1849186509[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1849186509.slideUp();
#                         link_1849186509[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="127385231" href="javascript:toggle_input_127385231()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_127385231;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_127385231 = document.getElementById("127385231");
#                 var cell = link_127385231;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_127385231;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_127385231 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_127385231 = cell.previousElementSibling;
#                 }
#                 input_127385231.style.display = "none"; // hide
#
#                 toggle_input_127385231 = function() {
#                     if (input_127385231.style.display == "none") {
#                         input_127385231.style.display = ""; // show
#                         link_127385231.innerHTML = "Hide Input";
#                     } else {
#                         input_127385231.style.display = "none"; // hide
#                         link_127385231.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_127385231 = $("a[id='127385231']");
#                 var cell_127385231 = link_127385231.parents("div.cell:first");
#                 if (cell_127385231.length == 0) {
#                     cell_127385231 = link_127385231.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_127385231 = cell_127385231.children("div.input");
#                 if (input_127385231.length == 0) {
#                     input_127385231 = cell_127385231.prev("div.nbinput");
#                 }
#                 input_127385231.hide();
#
#                 toggle_input_127385231 = function() {
#                     if (input_127385231.is(':hidden')) {
#                         input_127385231.slideDown();
#                         link_127385231[0].innerHTML = "Hide Input";
#                     } else {
#                         input_127385231.slideUp();
#                         link_127385231[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="2009554272" href="javascript:toggle_input_2009554272()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2009554272;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2009554272 = document.getElementById("2009554272");
#                 var cell = link_2009554272;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2009554272;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2009554272 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2009554272 = cell.previousElementSibling;
#                 }
#                 input_2009554272.style.display = "none"; // hide
#
#                 toggle_input_2009554272 = function() {
#                     if (input_2009554272.style.display == "none") {
#                         input_2009554272.style.display = ""; // show
#                         link_2009554272.innerHTML = "Hide Input";
#                     } else {
#                         input_2009554272.style.display = "none"; // hide
#                         link_2009554272.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2009554272 = $("a[id='2009554272']");
#                 var cell_2009554272 = link_2009554272.parents("div.cell:first");
#                 if (cell_2009554272.length == 0) {
#                     cell_2009554272 = link_2009554272.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2009554272 = cell_2009554272.children("div.input");
#                 if (input_2009554272.length == 0) {
#                     input_2009554272 = cell_2009554272.prev("div.nbinput");
#                 }
#                 input_2009554272.hide();
#
#                 toggle_input_2009554272 = function() {
#                     if (input_2009554272.is(':hidden')) {
#                         input_2009554272.slideDown();
#                         link_2009554272[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2009554272.slideUp();
#                         link_2009554272[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="287082278" href="javascript:toggle_input_287082278()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_287082278;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_287082278 = document.getElementById("287082278");
#                 var cell = link_287082278;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_287082278;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_287082278 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_287082278 = cell.previousElementSibling;
#                 }
#                 input_287082278.style.display = "none"; // hide
#
#                 toggle_input_287082278 = function() {
#                     if (input_287082278.style.display == "none") {
#                         input_287082278.style.display = ""; // show
#                         link_287082278.innerHTML = "Hide Input";
#                     } else {
#                         input_287082278.style.display = "none"; // hide
#                         link_287082278.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_287082278 = $("a[id='287082278']");
#                 var cell_287082278 = link_287082278.parents("div.cell:first");
#                 if (cell_287082278.length == 0) {
#                     cell_287082278 = link_287082278.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_287082278 = cell_287082278.children("div.input");
#                 if (input_287082278.length == 0) {
#                     input_287082278 = cell_287082278.prev("div.nbinput");
#                 }
#                 input_287082278.hide();
#
#                 toggle_input_287082278 = function() {
#                     if (input_287082278.is(':hidden')) {
#                         input_287082278.slideDown();
#                         link_287082278[0].innerHTML = "Hide Input";
#                     } else {
#                         input_287082278.slideUp();
#                         link_287082278[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="404306559" href="javascript:toggle_input_404306559()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_404306559;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_404306559 = document.getElementById("404306559");
#                 var cell = link_404306559;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_404306559;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_404306559 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_404306559 = cell.previousElementSibling;
#                 }
#                 input_404306559.style.display = "none"; // hide
#
#                 toggle_input_404306559 = function() {
#                     if (input_404306559.style.display == "none") {
#                         input_404306559.style.display = ""; // show
#                         link_404306559.innerHTML = "Hide Input";
#                     } else {
#                         input_404306559.style.display = "none"; // hide
#                         link_404306559.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_404306559 = $("a[id='404306559']");
#                 var cell_404306559 = link_404306559.parents("div.cell:first");
#                 if (cell_404306559.length == 0) {
#                     cell_404306559 = link_404306559.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_404306559 = cell_404306559.children("div.input");
#                 if (input_404306559.length == 0) {
#                     input_404306559 = cell_404306559.prev("div.nbinput");
#                 }
#                 input_404306559.hide();
#
#                 toggle_input_404306559 = function() {
#                     if (input_404306559.is(':hidden')) {
#                         input_404306559.slideDown();
#                         link_404306559[0].innerHTML = "Hide Input";
#                     } else {
#                         input_404306559.slideUp();
#                         link_404306559[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1907466623" href="javascript:toggle_input_1907466623()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1907466623;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1907466623 = document.getElementById("1907466623");
#                 var cell = link_1907466623;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1907466623;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1907466623 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1907466623 = cell.previousElementSibling;
#                 }
#                 input_1907466623.style.display = "none"; // hide
#
#                 toggle_input_1907466623 = function() {
#                     if (input_1907466623.style.display == "none") {
#                         input_1907466623.style.display = ""; // show
#                         link_1907466623.innerHTML = "Hide Input";
#                     } else {
#                         input_1907466623.style.display = "none"; // hide
#                         link_1907466623.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1907466623 = $("a[id='1907466623']");
#                 var cell_1907466623 = link_1907466623.parents("div.cell:first");
#                 if (cell_1907466623.length == 0) {
#                     cell_1907466623 = link_1907466623.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1907466623 = cell_1907466623.children("div.input");
#                 if (input_1907466623.length == 0) {
#                     input_1907466623 = cell_1907466623.prev("div.nbinput");
#                 }
#                 input_1907466623.hide();
#
#                 toggle_input_1907466623 = function() {
#                     if (input_1907466623.is(':hidden')) {
#                         input_1907466623.slideDown();
#                         link_1907466623[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1907466623.slideUp();
#                         link_1907466623[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1514495730" href="javascript:toggle_input_1514495730()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1514495730;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1514495730 = document.getElementById("1514495730");
#                 var cell = link_1514495730;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1514495730;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1514495730 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1514495730 = cell.previousElementSibling;
#                 }
#                 input_1514495730.style.display = "none"; // hide
#
#                 toggle_input_1514495730 = function() {
#                     if (input_1514495730.style.display == "none") {
#                         input_1514495730.style.display = ""; // show
#                         link_1514495730.innerHTML = "Hide Input";
#                     } else {
#                         input_1514495730.style.display = "none"; // hide
#                         link_1514495730.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1514495730 = $("a[id='1514495730']");
#                 var cell_1514495730 = link_1514495730.parents("div.cell:first");
#                 if (cell_1514495730.length == 0) {
#                     cell_1514495730 = link_1514495730.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1514495730 = cell_1514495730.children("div.input");
#                 if (input_1514495730.length == 0) {
#                     input_1514495730 = cell_1514495730.prev("div.nbinput");
#                 }
#                 input_1514495730.hide();
#
#                 toggle_input_1514495730 = function() {
#                     if (input_1514495730.is(':hidden')) {
#                         input_1514495730.slideDown();
#                         link_1514495730[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1514495730.slideUp();
#                         link_1514495730[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="178004608" href="javascript:toggle_input_178004608()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_178004608;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_178004608 = document.getElementById("178004608");
#                 var cell = link_178004608;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_178004608;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_178004608 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_178004608 = cell.previousElementSibling;
#                 }
#                 input_178004608.style.display = "none"; // hide
#
#                 toggle_input_178004608 = function() {
#                     if (input_178004608.style.display == "none") {
#                         input_178004608.style.display = ""; // show
#                         link_178004608.innerHTML = "Hide Input";
#                     } else {
#                         input_178004608.style.display = "none"; // hide
#                         link_178004608.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_178004608 = $("a[id='178004608']");
#                 var cell_178004608 = link_178004608.parents("div.cell:first");
#                 if (cell_178004608.length == 0) {
#                     cell_178004608 = link_178004608.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_178004608 = cell_178004608.children("div.input");
#                 if (input_178004608.length == 0) {
#                     input_178004608 = cell_178004608.prev("div.nbinput");
#                 }
#                 input_178004608.hide();
#
#                 toggle_input_178004608 = function() {
#                     if (input_178004608.is(':hidden')) {
#                         input_178004608.slideDown();
#                         link_178004608[0].innerHTML = "Hide Input";
#                     } else {
#                         input_178004608.slideUp();
#                         link_178004608[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x**2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="996125278" href="javascript:toggle_input_996125278()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_996125278;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_996125278 = document.getElementById("996125278");
#                 var cell = link_996125278;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_996125278;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_996125278 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_996125278 = cell.previousElementSibling;
#                 }
#                 input_996125278.style.display = "none"; // hide
#
#                 toggle_input_996125278 = function() {
#                     if (input_996125278.style.display == "none") {
#                         input_996125278.style.display = ""; // show
#                         link_996125278.innerHTML = "Hide Input";
#                     } else {
#                         input_996125278.style.display = "none"; // hide
#                         link_996125278.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_996125278 = $("a[id='996125278']");
#                 var cell_996125278 = link_996125278.parents("div.cell:first");
#                 if (cell_996125278.length == 0) {
#                     cell_996125278 = link_996125278.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_996125278 = cell_996125278.children("div.input");
#                 if (input_996125278.length == 0) {
#                     input_996125278 = cell_996125278.prev("div.nbinput");
#                 }
#                 input_996125278.hide();
#
#                 toggle_input_996125278 = function() {
#                     if (input_996125278.is(':hidden')) {
#                         input_996125278.slideDown();
#                         link_996125278[0].innerHTML = "Hide Input";
#                     } else {
#                         input_996125278.slideUp();
#                         link_996125278[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="540793716" href="javascript:toggle_input_540793716()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_540793716;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_540793716 = document.getElementById("540793716");
#                 var cell = link_540793716;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_540793716;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_540793716 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_540793716 = cell.previousElementSibling;
#                 }
#                 input_540793716.style.display = "none"; // hide
#
#                 toggle_input_540793716 = function() {
#                     if (input_540793716.style.display == "none") {
#                         input_540793716.style.display = ""; // show
#                         link_540793716.innerHTML = "Hide Input";
#                     } else {
#                         input_540793716.style.display = "none"; // hide
#                         link_540793716.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_540793716 = $("a[id='540793716']");
#                 var cell_540793716 = link_540793716.parents("div.cell:first");
#                 if (cell_540793716.length == 0) {
#                     cell_540793716 = link_540793716.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_540793716 = cell_540793716.children("div.input");
#                 if (input_540793716.length == 0) {
#                     input_540793716 = cell_540793716.prev("div.nbinput");
#                 }
#                 input_540793716.hide();
#
#                 toggle_input_540793716 = function() {
#                     if (input_540793716.is(':hidden')) {
#                         input_540793716.slideDown();
#                         link_540793716[0].innerHTML = "Hide Input";
#                     } else {
#                         input_540793716.slideUp();
#                         link_540793716[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
