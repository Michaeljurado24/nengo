# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book "Neural Engineering"](
# https://www.amazon.com/Neural-Engineering-Representation-Neurobiological-Computational/dp/0262550601).
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1675674960" href="javascript:toggle_input_1675674960()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1675674960;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1675674960 = document.getElementById("1675674960");
#                 var cell = link_1675674960;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1675674960;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1675674960 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1675674960 = cell.previousElementSibling;
#                 }
#                 input_1675674960.style.display = "none"; // hide
#
#                 toggle_input_1675674960 = function() {
#                     if (input_1675674960.style.display == "none") {
#                         input_1675674960.style.display = ""; // show
#                         link_1675674960.innerHTML = "Hide Input";
#                     } else {
#                         input_1675674960.style.display = "none"; // hide
#                         link_1675674960.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1675674960 = $("a[id='1675674960']");
#                 var cell_1675674960 = link_1675674960.parents("div.cell:first");
#                 if (cell_1675674960.length == 0) {
#                     cell_1675674960 = link_1675674960.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1675674960 = cell_1675674960.children("div.input");
#                 if (input_1675674960.length == 0) {
#                     input_1675674960 = cell_1675674960.prev("div.nbinput");
#                 }
#                 input_1675674960.hide();
#
#                 toggle_input_1675674960 = function() {
#                     if (input_1675674960.is(':hidden')) {
#                         input_1675674960.slideDown();
#                         link_1675674960[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1675674960.slideUp();
#                         link_1675674960[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="651079672" href="javascript:toggle_input_651079672()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_651079672;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_651079672 = document.getElementById("651079672");
#                 var cell = link_651079672;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_651079672;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_651079672 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_651079672 = cell.previousElementSibling;
#                 }
#                 input_651079672.style.display = "none"; // hide
#
#                 toggle_input_651079672 = function() {
#                     if (input_651079672.style.display == "none") {
#                         input_651079672.style.display = ""; // show
#                         link_651079672.innerHTML = "Hide Input";
#                     } else {
#                         input_651079672.style.display = "none"; // hide
#                         link_651079672.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_651079672 = $("a[id='651079672']");
#                 var cell_651079672 = link_651079672.parents("div.cell:first");
#                 if (cell_651079672.length == 0) {
#                     cell_651079672 = link_651079672.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_651079672 = cell_651079672.children("div.input");
#                 if (input_651079672.length == 0) {
#                     input_651079672 = cell_651079672.prev("div.nbinput");
#                 }
#                 input_651079672.hide();
#
#                 toggle_input_651079672 = function() {
#                     if (input_651079672.is(':hidden')) {
#                         input_651079672.slideDown();
#                         link_651079672[0].innerHTML = "Hide Input";
#                     } else {
#                         input_651079672.slideUp();
#                         link_651079672[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="1775260112" href="javascript:toggle_input_1775260112()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1775260112;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1775260112 = document.getElementById("1775260112");
#                 var cell = link_1775260112;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1775260112;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1775260112 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1775260112 = cell.previousElementSibling;
#                 }
#                 input_1775260112.style.display = "none"; // hide
#
#                 toggle_input_1775260112 = function() {
#                     if (input_1775260112.style.display == "none") {
#                         input_1775260112.style.display = ""; // show
#                         link_1775260112.innerHTML = "Hide Input";
#                     } else {
#                         input_1775260112.style.display = "none"; // hide
#                         link_1775260112.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1775260112 = $("a[id='1775260112']");
#                 var cell_1775260112 = link_1775260112.parents("div.cell:first");
#                 if (cell_1775260112.length == 0) {
#                     cell_1775260112 = link_1775260112.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1775260112 = cell_1775260112.children("div.input");
#                 if (input_1775260112.length == 0) {
#                     input_1775260112 = cell_1775260112.prev("div.nbinput");
#                 }
#                 input_1775260112.hide();
#
#                 toggle_input_1775260112 = function() {
#                     if (input_1775260112.is(':hidden')) {
#                         input_1775260112.slideDown();
#                         link_1775260112[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1775260112.slideUp();
#                         link_1775260112[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="1032168350" href="javascript:toggle_input_1032168350()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1032168350;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1032168350 = document.getElementById("1032168350");
#                 var cell = link_1032168350;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1032168350;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1032168350 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1032168350 = cell.previousElementSibling;
#                 }
#                 input_1032168350.style.display = "none"; // hide
#
#                 toggle_input_1032168350 = function() {
#                     if (input_1032168350.style.display == "none") {
#                         input_1032168350.style.display = ""; // show
#                         link_1032168350.innerHTML = "Hide Input";
#                     } else {
#                         input_1032168350.style.display = "none"; // hide
#                         link_1032168350.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1032168350 = $("a[id='1032168350']");
#                 var cell_1032168350 = link_1032168350.parents("div.cell:first");
#                 if (cell_1032168350.length == 0) {
#                     cell_1032168350 = link_1032168350.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1032168350 = cell_1032168350.children("div.input");
#                 if (input_1032168350.length == 0) {
#                     input_1032168350 = cell_1032168350.prev("div.nbinput");
#                 }
#                 input_1032168350.hide();
#
#                 toggle_input_1032168350 = function() {
#                     if (input_1032168350.is(':hidden')) {
#                         input_1032168350.slideDown();
#                         link_1032168350[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1032168350.slideUp();
#                         link_1032168350[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="1491023165" href="javascript:toggle_input_1491023165()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1491023165;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1491023165 = document.getElementById("1491023165");
#                 var cell = link_1491023165;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1491023165;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1491023165 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1491023165 = cell.previousElementSibling;
#                 }
#                 input_1491023165.style.display = "none"; // hide
#
#                 toggle_input_1491023165 = function() {
#                     if (input_1491023165.style.display == "none") {
#                         input_1491023165.style.display = ""; // show
#                         link_1491023165.innerHTML = "Hide Input";
#                     } else {
#                         input_1491023165.style.display = "none"; // hide
#                         link_1491023165.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1491023165 = $("a[id='1491023165']");
#                 var cell_1491023165 = link_1491023165.parents("div.cell:first");
#                 if (cell_1491023165.length == 0) {
#                     cell_1491023165 = link_1491023165.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1491023165 = cell_1491023165.children("div.input");
#                 if (input_1491023165.length == 0) {
#                     input_1491023165 = cell_1491023165.prev("div.nbinput");
#                 }
#                 input_1491023165.hide();
#
#                 toggle_input_1491023165 = function() {
#                     if (input_1491023165.is(':hidden')) {
#                         input_1491023165.slideDown();
#                         link_1491023165[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1491023165.slideUp();
#                         link_1491023165[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="164971690" href="javascript:toggle_input_164971690()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_164971690;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_164971690 = document.getElementById("164971690");
#                 var cell = link_164971690;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_164971690;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_164971690 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_164971690 = cell.previousElementSibling;
#                 }
#                 input_164971690.style.display = "none"; // hide
#
#                 toggle_input_164971690 = function() {
#                     if (input_164971690.style.display == "none") {
#                         input_164971690.style.display = ""; // show
#                         link_164971690.innerHTML = "Hide Input";
#                     } else {
#                         input_164971690.style.display = "none"; // hide
#                         link_164971690.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_164971690 = $("a[id='164971690']");
#                 var cell_164971690 = link_164971690.parents("div.cell:first");
#                 if (cell_164971690.length == 0) {
#                     cell_164971690 = link_164971690.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_164971690 = cell_164971690.children("div.input");
#                 if (input_164971690.length == 0) {
#                     input_164971690 = cell_164971690.prev("div.nbinput");
#                 }
#                 input_164971690.hide();
#
#                 toggle_input_164971690 = function() {
#                     if (input_164971690.is(':hidden')) {
#                         input_164971690.slideDown();
#                         link_164971690[0].innerHTML = "Hide Input";
#                     } else {
#                         input_164971690.slideUp();
#                         link_164971690[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="2144183609" href="javascript:toggle_input_2144183609()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2144183609;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2144183609 = document.getElementById("2144183609");
#                 var cell = link_2144183609;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2144183609;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2144183609 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2144183609 = cell.previousElementSibling;
#                 }
#                 input_2144183609.style.display = "none"; // hide
#
#                 toggle_input_2144183609 = function() {
#                     if (input_2144183609.style.display == "none") {
#                         input_2144183609.style.display = ""; // show
#                         link_2144183609.innerHTML = "Hide Input";
#                     } else {
#                         input_2144183609.style.display = "none"; // hide
#                         link_2144183609.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2144183609 = $("a[id='2144183609']");
#                 var cell_2144183609 = link_2144183609.parents("div.cell:first");
#                 if (cell_2144183609.length == 0) {
#                     cell_2144183609 = link_2144183609.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2144183609 = cell_2144183609.children("div.input");
#                 if (input_2144183609.length == 0) {
#                     input_2144183609 = cell_2144183609.prev("div.nbinput");
#                 }
#                 input_2144183609.hide();
#
#                 toggle_input_2144183609 = function() {
#                     if (input_2144183609.is(':hidden')) {
#                         input_2144183609.slideDown();
#                         link_2144183609[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2144183609.slideUp();
#                         link_2144183609[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="72821034" href="javascript:toggle_input_72821034()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_72821034;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_72821034 = document.getElementById("72821034");
#                 var cell = link_72821034;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_72821034;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_72821034 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_72821034 = cell.previousElementSibling;
#                 }
#                 input_72821034.style.display = "none"; // hide
#
#                 toggle_input_72821034 = function() {
#                     if (input_72821034.style.display == "none") {
#                         input_72821034.style.display = ""; // show
#                         link_72821034.innerHTML = "Hide Input";
#                     } else {
#                         input_72821034.style.display = "none"; // hide
#                         link_72821034.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_72821034 = $("a[id='72821034']");
#                 var cell_72821034 = link_72821034.parents("div.cell:first");
#                 if (cell_72821034.length == 0) {
#                     cell_72821034 = link_72821034.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_72821034 = cell_72821034.children("div.input");
#                 if (input_72821034.length == 0) {
#                     input_72821034 = cell_72821034.prev("div.nbinput");
#                 }
#                 input_72821034.hide();
#
#                 toggle_input_72821034 = function() {
#                     if (input_72821034.is(':hidden')) {
#                         input_72821034.slideDown();
#                         link_72821034[0].innerHTML = "Hide Input";
#                     } else {
#                         input_72821034.slideUp();
#                         link_72821034[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1389683994" href="javascript:toggle_input_1389683994()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1389683994;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1389683994 = document.getElementById("1389683994");
#                 var cell = link_1389683994;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1389683994;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1389683994 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1389683994 = cell.previousElementSibling;
#                 }
#                 input_1389683994.style.display = "none"; // hide
#
#                 toggle_input_1389683994 = function() {
#                     if (input_1389683994.style.display == "none") {
#                         input_1389683994.style.display = ""; // show
#                         link_1389683994.innerHTML = "Hide Input";
#                     } else {
#                         input_1389683994.style.display = "none"; // hide
#                         link_1389683994.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1389683994 = $("a[id='1389683994']");
#                 var cell_1389683994 = link_1389683994.parents("div.cell:first");
#                 if (cell_1389683994.length == 0) {
#                     cell_1389683994 = link_1389683994.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1389683994 = cell_1389683994.children("div.input");
#                 if (input_1389683994.length == 0) {
#                     input_1389683994 = cell_1389683994.prev("div.nbinput");
#                 }
#                 input_1389683994.hide();
#
#                 toggle_input_1389683994 = function() {
#                     if (input_1389683994.is(':hidden')) {
#                         input_1389683994.slideDown();
#                         link_1389683994[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1389683994.slideUp();
#                         link_1389683994[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="332370525" href="javascript:toggle_input_332370525()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_332370525;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_332370525 = document.getElementById("332370525");
#                 var cell = link_332370525;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_332370525;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_332370525 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_332370525 = cell.previousElementSibling;
#                 }
#                 input_332370525.style.display = "none"; // hide
#
#                 toggle_input_332370525 = function() {
#                     if (input_332370525.style.display == "none") {
#                         input_332370525.style.display = ""; // show
#                         link_332370525.innerHTML = "Hide Input";
#                     } else {
#                         input_332370525.style.display = "none"; // hide
#                         link_332370525.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_332370525 = $("a[id='332370525']");
#                 var cell_332370525 = link_332370525.parents("div.cell:first");
#                 if (cell_332370525.length == 0) {
#                     cell_332370525 = link_332370525.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_332370525 = cell_332370525.children("div.input");
#                 if (input_332370525.length == 0) {
#                     input_332370525 = cell_332370525.prev("div.nbinput");
#                 }
#                 input_332370525.hide();
#
#                 toggle_input_332370525 = function() {
#                     if (input_332370525.is(':hidden')) {
#                         input_332370525.slideDown();
#                         link_332370525[0].innerHTML = "Hide Input";
#                     } else {
#                         input_332370525.slideUp();
#                         link_332370525[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="123930572" href="javascript:toggle_input_123930572()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_123930572;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_123930572 = document.getElementById("123930572");
#                 var cell = link_123930572;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_123930572;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_123930572 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_123930572 = cell.previousElementSibling;
#                 }
#                 input_123930572.style.display = "none"; // hide
#
#                 toggle_input_123930572 = function() {
#                     if (input_123930572.style.display == "none") {
#                         input_123930572.style.display = ""; // show
#                         link_123930572.innerHTML = "Hide Input";
#                     } else {
#                         input_123930572.style.display = "none"; // hide
#                         link_123930572.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_123930572 = $("a[id='123930572']");
#                 var cell_123930572 = link_123930572.parents("div.cell:first");
#                 if (cell_123930572.length == 0) {
#                     cell_123930572 = link_123930572.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_123930572 = cell_123930572.children("div.input");
#                 if (input_123930572.length == 0) {
#                     input_123930572 = cell_123930572.prev("div.nbinput");
#                 }
#                 input_123930572.hide();
#
#                 toggle_input_123930572 = function() {
#                     if (input_123930572.is(':hidden')) {
#                         input_123930572.slideDown();
#                         link_123930572[0].innerHTML = "Hide Input";
#                     } else {
#                         input_123930572.slideUp();
#                         link_123930572[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="479330075" href="javascript:toggle_input_479330075()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_479330075;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_479330075 = document.getElementById("479330075");
#                 var cell = link_479330075;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_479330075;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_479330075 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_479330075 = cell.previousElementSibling;
#                 }
#                 input_479330075.style.display = "none"; // hide
#
#                 toggle_input_479330075 = function() {
#                     if (input_479330075.style.display == "none") {
#                         input_479330075.style.display = ""; // show
#                         link_479330075.innerHTML = "Hide Input";
#                     } else {
#                         input_479330075.style.display = "none"; // hide
#                         link_479330075.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_479330075 = $("a[id='479330075']");
#                 var cell_479330075 = link_479330075.parents("div.cell:first");
#                 if (cell_479330075.length == 0) {
#                     cell_479330075 = link_479330075.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_479330075 = cell_479330075.children("div.input");
#                 if (input_479330075.length == 0) {
#                     input_479330075 = cell_479330075.prev("div.nbinput");
#                 }
#                 input_479330075.hide();
#
#                 toggle_input_479330075 = function() {
#                     if (input_479330075.is(':hidden')) {
#                         input_479330075.slideDown();
#                         link_479330075[0].innerHTML = "Hide Input";
#                     } else {
#                         input_479330075.slideUp();
#                         link_479330075[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="957077759" href="javascript:toggle_input_957077759()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_957077759;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_957077759 = document.getElementById("957077759");
#                 var cell = link_957077759;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_957077759;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_957077759 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_957077759 = cell.previousElementSibling;
#                 }
#                 input_957077759.style.display = "none"; // hide
#
#                 toggle_input_957077759 = function() {
#                     if (input_957077759.style.display == "none") {
#                         input_957077759.style.display = ""; // show
#                         link_957077759.innerHTML = "Hide Input";
#                     } else {
#                         input_957077759.style.display = "none"; // hide
#                         link_957077759.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_957077759 = $("a[id='957077759']");
#                 var cell_957077759 = link_957077759.parents("div.cell:first");
#                 if (cell_957077759.length == 0) {
#                     cell_957077759 = link_957077759.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_957077759 = cell_957077759.children("div.input");
#                 if (input_957077759.length == 0) {
#                     input_957077759 = cell_957077759.prev("div.nbinput");
#                 }
#                 input_957077759.hide();
#
#                 toggle_input_957077759 = function() {
#                     if (input_957077759.is(':hidden')) {
#                         input_957077759.slideDown();
#                         link_957077759[0].innerHTML = "Hide Input";
#                     } else {
#                         input_957077759.slideUp();
#                         link_957077759[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
